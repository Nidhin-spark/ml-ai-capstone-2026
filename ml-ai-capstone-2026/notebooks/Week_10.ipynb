# %% [markdown]
# # Week 10: BBO Capstone
#
# Nidhin Raj | Imperial College

# %% [markdown]
# ## Strategy
#
# Adaptive allocation of queries by ROI: F5/F7 got exploitation (chase records), F1/F6 got exploratory (understand structure), F2-F4 got balanced. Weekly budget redistribution based on progress.

# %% [markdown]
# ## Results
#
# | Function | Output |
# |----------|--------|
# | F1 | 0.000620 |
# | F2 | 0.445598 |
# | F3 | 0.445598 |
# | F4 | 0.445598 |
# | F5 | 1584.961538 |
# | F6 | -0.000006 |
# | F7 | 0.174558 |
# | F8 | 0.445598 |

# %% [markdown]
# ## Key Decision
#
# F1 and F6 plateaued despite repeated attempts around 0.4-0.6, so shifted to aggressive boundary testing at periphery (0.425, 0.575).

# %% [markdown]
# ## Lesson Learned
#
# Realized assumption of local smoothness violated in narrow-peak regions. F1's near-zero plateau except narrow regions forced strategy rethink.

# %% [markdown]
# ## Next
#
# Week 11: Continue adaptive strategy.
