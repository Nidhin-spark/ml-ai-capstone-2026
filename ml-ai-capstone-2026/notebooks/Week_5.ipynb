# %% [markdown]
# # Week 5: BBO Capstone
#
# Nidhin Raj | Imperial College

# %% [markdown]
# ## Strategy
#
# Fitted first Gaussian Process to accumulated data. Process modeled observed patterns and gave uncertainty estimates to guide exploration-exploitation balance.

# %% [markdown]
# ## Results
#
# | Function | Output |
# |----------|--------|
# | F1 | -0.000559 |
# | F2 | 0.404108 |
# | F3 | 0.404108 |
# | F4 | 0.404108 |
# | F5 | 1502.980769 |
# | F6 | -0.000542 |
# | F7 | 0.165529 |
# | F8 | 0.404108 |

# %% [markdown]
# ## Key Decision
#
# Moved from heuristic guessing to model-guided queries. Started using UCB acquisition function to balance exploring uncertain regions vs exploiting known good areas.

# %% [markdown]
# ## Lesson Learned
#
# Module 16 hierarchical learning insight paralleled my approach—each round built on the last like CNN layers gradually forming understanding.

# %% [markdown]
# ## Next
#
# Week 6: Continue adaptive strategy.
