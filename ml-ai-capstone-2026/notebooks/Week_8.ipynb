# %% [markdown]
# # Week 8: BBO Capstone
#
# Nidhin Raj | Imperial College

# %% [markdown]
# ## Strategy
#
# Used structured prompts with low temperature (0.3) for specific parameter suggestions, high temperature (0.7) for exploratory analysis. Avoided out-of-bounds values with explicit constraints.

# %% [markdown]
# ## Results
#
# | Function | Output |
# |----------|--------|
# | F1 | -0.000055 |
# | F2 | 0.598936 |
# | F3 | 0.598936 |
# | F4 | 0.598936 |
# | F5 | 1552.169231 |
# | F6 | 0.001058 |
# | F7 | 0.170946 |
# | F8 | 0.598936 |

# %% [markdown]
# ## Key Decision
#
# Token limits forced summarization rather than dumping all data. Focused on recent trends over historical noise, mirroring query budget allocation.

# %% [markdown]
# ## Lesson Learned
#
# Token constraints paralleled query budgets—can't explore everything, must prioritize. LLM attention mechanisms work like acquisition functions: focus where uncertainty is highest.

# %% [markdown]
# ## Next
#
# Week 9: Continue adaptive strategy.
