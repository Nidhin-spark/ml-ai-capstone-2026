# %% [markdown]
# # Week 4: BBO Capstone
#
# Nidhin Raj | Imperial College

# %% [markdown]
# ## Strategy
#
# With 3 data points per function, stayed focused on exploration rather than fitting complex models. Spread queries across search space to identify regions of rapid change.

# %% [markdown]
# ## Results
#
# | Function | Output |
# |----------|--------|
# | F1 | 0.000585 |
# | F2 | 0.424320 |
# | F3 | 0.424320 |
# | F4 | 0.424320 |
# | F5 | 1486.584615 |
# | F6 | 0.000332 |
# | F7 | 0.163723 |
# | F8 | 0.424320 |

# %% [markdown]
# ## Key Decision
#
# Deliberately chose not to build neural networks with sparse data—would overfit. Decided to start Gaussian Process in next round once more data accumulated.

# %% [markdown]
# ## Lesson Learned
#
# Learned that with limited data, simpler models work better than complex ones. Overfitting risk was real; patience to gather data first was the right call.

# %% [markdown]
# ## Next
#
# Week 5: Continue adaptive strategy.
