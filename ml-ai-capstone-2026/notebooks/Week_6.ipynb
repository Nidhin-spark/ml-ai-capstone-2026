# %% [markdown]
# # Week 6: BBO Capstone
#
# Nidhin Raj | Imperial College

# %% [markdown]
# ## Strategy
#
# Progressive feature extraction like CNNs—early rounds detected search space edges, middle rounds explored center, recent rounds filled gaps. Each layer built on previous.

# %% [markdown]
# ## Results
#
# | Function | Output |
# |----------|--------|
# | F1 | -0.000891 |
# | F2 | 0.472058 |
# | F3 | 0.472058 |
# | F4 | 0.472058 |
# | F5 | 1519.376923 |
# | F6 | 0.000261 |
# | F7 | 0.167335 |
# | F8 | 0.472058 |

# %% [markdown]
# ## Key Decision
#
# Reduced GP length scale for functions showing local peaks, increased for smooth surfaces. Started per-function hyperparameter tuning instead of one-size-fits-all.

# %% [markdown]
# ## Lesson Learned
#
# CNN concept of pooling reminded me not all data points matter equally—landmarks matter more than noise. Prevented overfitting to meaningless variation.

# %% [markdown]
# ## Next
#
# Week 7: Continue adaptive strategy.
