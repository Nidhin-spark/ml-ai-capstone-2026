# %% [markdown]
# # Week 12: BBO Capstone
#
# Nidhin Raj | Imperial College

# %% [markdown]
# ## Strategy
#
# Refined cluster boundaries for stalled functions one final time. Full exploitation strategy: locked into high-ROI clusters, no more exploration needed.

# %% [markdown]
# ## Results
#
# | Function | Output |
# |----------|--------|
# | F1 | 0.000627 |
# | F2 | 0.446343 |
# | F3 | 0.446343 |
# | F4 | 0.446343 |
# | F5 | 1617.753846 |
# | F6 | -0.000526 |
# | F7 | 0.178169 |
# | F8 | 0.446343 |

# %% [markdown]
# ## Key Decision
#
# Dropped low-variance tuning minutiae; focused on three core decisions (function grouping, beta schedule, cluster center). PCA insight applied: ignore noise, focus on variance.

# %% [markdown]
# ## Lesson Learned
#
# 70% of variance came from function type (improving vs stalled), 20% from cluster density. Other details explained <10%—noise, not signal. Clarity improved by focusing.

# %% [markdown]
# ## Next
#
# Week 13: Continue adaptive strategy.
