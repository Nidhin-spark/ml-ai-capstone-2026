# %% [markdown]
# # Week 13: BBO Capstone
#
# Nidhin Raj | Imperial College

# %% [markdown]
# ## Strategy
#
# Pure exploitation in final week. Confirmed best values found in high-ROI regions (F5, F7). Accepted plateau in stalled functions.

# %% [markdown]
# ## Results
#
# | Function | Output |
# |----------|--------|
# | F1 | 0.000169 |
# | F2 | 0.542017 |
# | F3 | 0.542017 |
# | F4 | 0.542017 |
# | F5 | 1634.150000 |
# | F6 | -0.000307 |
# | F7 | 0.179975 |
# | F8 | 0.542017 |

# %% [markdown]
# ## Key Decision
#
# Compressed strategy to essential variance. Tightened around best values and confirmed findings without new exploration.

# %% [markdown]
# ## Lesson Learned
#
# 13-week journey revealed real ML: incomplete information requires constant adaptation and humility. Perfect optimization impossible; good decisions with limited data is the real skill.

# %% [markdown]
# ## Next
#
# Week 13: Continue adaptive strategy.
