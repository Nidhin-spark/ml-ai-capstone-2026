# %% [markdown]
# # Week 1: BBO Capstone
#
# Nidhin Raj | Imperial College

# %% [markdown]
# ## Strategy
#
# Started with exploratory queries across the search space to understand baseline function behavior. Tested varied, scattered values to establish initial understanding of each function's response.

# %% [markdown]
# ## Results
#
# | Function | Output |
# |----------|--------|
# | F1 | -0.000000 |
# | F2 | 0.450700 |
# | F3 | -0.138600 |
# | F4 | -6.045800 |
# | F5 | 1421.040000 |
# | F6 | -0.540600 |
# | F7 | 0.156500 |
# | F8 | 9.757600 |

# %% [markdown]
# ## Key Decision
#
# Chose 60% exploration and 40% exploitation balance in week 1, testing center points and extreme values. Didn't know where good regions were, so broad coverage was the priority.

# %% [markdown]
# ## Lesson Learned
#
# Learned that extreme values mostly performed poorly, giving me a useful baseline. Understanding the landscape early was more important than finding the peak immediately.

# %% [markdown]
# ## Next
#
# Week 2: Continue adaptive strategy.
