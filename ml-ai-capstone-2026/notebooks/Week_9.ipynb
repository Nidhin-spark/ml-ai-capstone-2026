# %% [markdown]
# # Week 9: BBO Capstone
#
# Nidhin Raj | Imperial College

# %% [markdown]
# ## Strategy
#
# Monitoring confidence intervals revealed emergent behavior around 12-15 data points. GP suddenly shifted from noisy individual results to coherent model representation.

# %% [markdown]
# ## Results
#
# | Function | Output |
# |----------|--------|
# | F1 | -0.000286 |
# | F2 | 0.541212 |
# | F3 | 0.541212 |
# | F4 | 0.541212 |
# | F5 | 1568.565385 |
# | F6 | -0.000151 |
# | F7 | 0.172752 |
# | F8 | 0.541212 |

# %% [markdown]
# ## Key Decision
#
# When uncertainty dropped sharply, had formed robust representation. Shifted strategy from exploration to exploitation at this phase transition.

# %% [markdown]
# ## Lesson Learned
#
# Scaling laws showed diminishing returns—early rounds gave steep improvements, by Week 6 gains plateaued. F5 and F7 improved steadily, F1 and F6 stalled.

# %% [markdown]
# ## Next
#
# Week 10: Continue adaptive strategy.
