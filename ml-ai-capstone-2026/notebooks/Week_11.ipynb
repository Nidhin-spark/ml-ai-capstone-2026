# %% [markdown]
# # Week 11: BBO Capstone
#
# Nidhin Raj | Imperial College

# %% [markdown]
# ## Strategy
#
# Grouped functions by improvement rate, assigned targeted beta values. This structure emerged from data, not guessing—like PCA finding principal directions of variance.

# %% [markdown]
# ## Results
#
# | Function | Output |
# |----------|--------|
# | F1 | -0.000743 |
# | F2 | 0.400001 |
# | F3 | 0.400001 |
# | F4 | 0.400001 |
# | F5 | 1601.357692 |
# | F6 | 0.000521 |
# | F7 | 0.176363 |
# | F8 | 0.400001 |

# %% [markdown]
# ## Key Decision
#
# Maintained tight clusters around 0.4-0.65 for F5/F7 while testing boundaries for F1/F6. Recognized clustering could trap you if commitment was premature.

# %% [markdown]
# ## Lesson Learned
#
# Clustering 70% of queries in [0.3, 0.7] left boundaries under-sampled. Limited confidence in F8 (8D with 19 points—fewer than 3 per dimension).

# %% [markdown]
# ## Next
#
# Week 12: Continue adaptive strategy.
