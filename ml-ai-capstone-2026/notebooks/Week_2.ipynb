# %% [markdown]
# # Week 2: BBO Capstone
#
# Nidhin Raj | Imperial College

# %% [markdown]
# ## Strategy
#
# Shifted to balanced center-point testing with systematic range exploration. Moved Function 1 from extremes to midpoint as a reference baseline.

# %% [markdown]
# ## Results
#
# | Function | Output |
# |----------|--------|
# | F1 | -0.000000 |
# | F2 | 0.587900 |
# | F3 | -0.055600 |
# | F4 | -7.363200 |
# | F5 | 2208.230000 |
# | F6 | -0.636400 |
# | F7 | 0.979100 |
# | F8 | 9.784100 |

# %% [markdown]
# ## Key Decision
#
# Tested symmetric values like 0.333333 for higher-dimensional functions based on heuristic that many peaks sit near central regions. 60% exploration, 40% exploitation continued.

# %% [markdown]
# ## Lesson Learned
#
# Recognized that understanding function behavior at symmetric points provides stable reference. Center-point testing proved more effective than pure random exploration.

# %% [markdown]
# ## Next
#
# Week 3: Continue adaptive strategy.
