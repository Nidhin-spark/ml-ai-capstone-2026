# %% [markdown]
# # Week 3: BBO Capstone
#
# Nidhin Raj | Imperial College

# %% [markdown]
# ## Strategy
#
# Approach became more refined and less random. Focused on smaller adjustments around promising 0.4-0.6 range instead of broad exploration.

# %% [markdown]
# ## Results
#
# | Function | Output |
# |----------|--------|
# | F1 | 0.000065 |
# | F2 | 0.514112 |
# | F3 | 0.514112 |
# | F4 | 0.514112 |
# | F5 | 1470.188462 |
# | F6 | 0.000772 |
# | F7 | 0.161917 |
# | F8 | 0.514112 |

# %% [markdown]
# ## Key Decision
#
# Concentrated queries on middle ranges that consistently performed better. Strategy evolved naturally from exploration to optimization as patterns emerged.

# %% [markdown]
# ## Lesson Learned
#
# Pattern recognition from accumulated data guided next week's choices. Realized good results in one region didn't guarantee true optimum, so continued cautious exploration.

# %% [markdown]
# ## Next
#
# Week 4: Continue adaptive strategy.
